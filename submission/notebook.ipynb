# %% [markdown]
# # Proyek Analisis Data: Brazilian E-Commerce Public Dataset by Olist
# - **Nama:** Albar Pambagio Arioseto
# - **Email:** albarpambagio@gmail.com
# - **ID Dicoding:** albarpambagio

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - 5 kota dengan jumlah order terbanyak?
# - 5 kota dengan nilai transaksi tertinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df_ct = pd.read_csv('data\olist_customers_dataset.csv')
df_pm = pd.read_csv('data\olist_order_payments_dataset.csv')
df_od = pd.read_csv('data\olist_orders_dataset.csv')

# %%
# Export to Excel with 3 sheets
with pd.ExcelWriter("brazilian_ecommerce_data.xlsx") as writer:
    df_ct.to_excel(writer, sheet_name="customers", index=False)
    df_pm.to_excel(writer, sheet_name="payments", index=False)
    df_od.to_excel(writer, sheet_name="orders", index=False)

# %% [markdown]
# **Insight:**
# - dataset bersumber dari kaggle
# - format dataset: csv

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Checking missing value

# %%
df_ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_od.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# #### Checking duplicates

# %%
df_ct.duplicated().sum()
# Out:
# 0

# %%
df_pm.duplicated().sum()
# Out:
# 0

# %%
df_od.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Checking outlier

# %%
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    return outliers

# %%
df_pm.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
outliers = detect_outliers_iqr(df_pm, 'payment_value')
outliers
# Out:
#                                 order_id  payment_sequential payment_type  \
# 23      4d680edbaa7d3d9bed69532957368a03                   1  credit_card
# 26      d0a945f85ba1074b60aac97ade7e240e                   1  credit_card
# 52      2e2c60b99754ae1e4d8b18846cfec9f2                   1  credit_card
# 54      95442deb81a5d91c97c0df96b431634a                   1       boleto
# 61      3ab4eea6776259ae8dfbabaeffece352                   1  credit_card
# ...                                  ...                 ...          ...
# 103814  df8ab61cb615d551483618533aceb364                   1  credit_card
# 103843  262bf694d9c87de7844dd80b98fcfef3                   1  credit_card
# 103861  691688405bcee3ff9023639514498962                   1  credit_card
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
#
#         payment_installments  payment_value
# 23                        10         353.09
# 26                         2         541.00
# 52                         4         542.66
# 54                         1         368.98
# 61                         8         387.80
# ...                      ...            ...
# 103814                    10         713.65
# 103843                     5         372.08
# 103861                     1         356.53
# 103881                     1         363.31
# 103884                     5         369.54
#
# [7981 rows x 5 columns]

# %%
df_pm['payment_value'].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
fig = px.box(df_pm, y='payment_value', title="Boxplot for payment value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d1bb2d9-5b8b-4fae-9fd4-ae4667c4ded6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d1bb2d9-5b8b-4fae-9fd4-ae4667c4ded6")) {                    Plotly.newPlot(                        "6d1bb2d9-5b8b-4fae-9fd4-ae4667c4ded6",                        [{"alignmentgroup":"True","hovertemplate":"payment_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":
368.6,107.78,387.27,107.23,101.25,26.09,244.35,117.85,171.32,202.44,73.03,264.67,68.7,55.13,92.99,36.0,17.87,58.38,50.0,1995.69,130.14,710.23,68.0,59.51,371.94,667.99,63.89,49.34,147.0,354.64,59.71,408.66,51.66,386.46,69.54,21.94,52.34,114.25,162.83,172.92,81.72,151.79,243.62,56.42,45.13,108.64,64.51,193.5,110.63,200.55,41.71,54.43,77.64,280.08,101.34,77.57,60.2,48.1,76.02,84.56,20.0,48.16,265.41,127.53,128.73,37.37,150.15,36.16,198.0,112.4,35.4,189.98,228.6,314.21,22.29,257.3,162.99,51.03,190.09,374.24,53.15,88.2,25.9,46.81,131.47,258.71, ...

# %%
# Merge df_od with df_ct on the common column (e.g., 'customer_id')
merged_df = df_od.merge(df_ct[['customer_city', 'customer_id']], on='customer_id', how='left')

# Group by 'customer_city' and count 'order_delivered_customer_date' in merged_df
count_orders = merged_df.groupby('customer_city')['order_delivered_customer_date'].count().reset_index()

count_orders.rename(columns={'order_delivered_customer_date': 'order_count'}, inplace=True)

# %%
count_orders.shape
# Out:
# (4119, 2)

# %%
detect_outliers_iqr(count_orders, 'order_count')
# Out:
#               customer_city  order_count
# 23               adamantina           35
# 50         aguas de lindoia           22
# 55    aguas lindas de goias           24
# 70               alagoinhas           40
# 76                 alegrete           35
# ...                     ...          ...
# 4088   vitoria da conquista           88
# 4097          volta redonda          227
# 4098             votorantim           84
# 4099            votuporanga           63
# 4109                xanxere           29
#
# [553 rows x 2 columns]

# %%
count_orders['order_count'].describe()
# Out:
# count     4119.000000
# mean        23.422190
# std        270.110405
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          8.000000
# max      15046.000000
# Name: order_count, dtype: float64

# %%
fig_o = px.box(count_orders, y='order_count', title="Boxplot for order_count")
fig_o.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="95d4a271-2103-4d44-8a7f-d181ba1a6335" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95d4a271-2103-4d44-8a7f-d181ba1a6335")) {                    Plotly.newPlot(                        "95d4a271-2103-4d44-8a7f-d181ba1a6335",                        [{"alignmentgroup":"True","hovertemplate":"order_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[3,1,12,11,2,2,2,3,1,6,1,5,11,2,7,1,8,1,2,7,7,2,1,35,1,5,1,1,8,11,2,1,1,1,2,18,5,2,2,1,4,1,1,1,1,2,9,6,1,10,22,3,2,5,1,24,1,3,1,16,1,10,1,4,1,2,1,1,1,2,40,3,1,6,4,17,35,1,1,28,1,2,1,5,43,7,1,3,2,2,1,2,1,14,1,35,1,2,1,7,12,3,25,2,2,3,1,4,3,2,1,1,5,0,5,2,8,2,2,3,2,9,2,5,1,4,2,3,1,3,3,5,13,2,2,8,2,11,56,1,1,3,6,1,1,2,2,1,1,3,1,216,3,17,1,2,1,63,1,8,2,1,4,1,85,111,2,1,17,1,11,5,12,40,1,3,1,8,1,1,1,1,1,1,83,1,3,1,1,1,1,8,5,2,3,4,10,1,2,3,1,1,2,5,3,1,25,1,105,1,2,1,7,12,6,0,6,7,3,1,1,1,51,2,1,3,1,213,8,21,1,138,4,3,2,5,11,40,9,3,1,1,1,38,1,2,54,5,2,1,1,3,1,2,29,1,2,32,5,9,1,4,11,1,18,150,93,2,2,1,11,74,5,1,1,2,54,5,75,7,25,5,6,7,3,2
,242,1,2,2,2,11,9,18,24,1,91,2,3,2,3,4,3,3,3,8,2,7,1,2,8,1,1,1,7,30,18,3,3,56,2,1,7,6,4,79,2,243,3,1,1,2,2,14,5,1,3,1489,20,4,7,1,1,3,3,1,42,5,2,2,1,2,1,3,4,1,2,2,2,13,3,1,1,1,1,1,276,1,5,27,7,7,1,23,2,2,3,2,1,13,1,1,7,5,132,1,1,2,1,2,1,11,17,3,1,27,3,3,1,5,5,1,1,10,3,4,2,2,9,1,2,2,8,0,7,4,2,1,9,63,1,0,1,2,27,10,1,1,3,250,2,2,8,4,6,15,5,3,1,2,10,1,11,157,46,2,11,8,4,1,0,12,1,2,6,1,6,7,3,3,1,1,56,1,1,2,7,10,1,14,19,6,5,3,2,2,6,6,18,2,5,7,5,9,20,39,1,1,7,3,15,1,1,2,3,1,1,5,2,1,5,36,13,1,42,2,1,1,27,10,3,4,9,11,1,4,29,2,181,5,1,1,1,1,14,2,1,1,6,52,1,109,1,2,8,4,2,1,7,2,1,2,1,2,2,12,1,11,1,3,3,18,557,1,4,1,1,1,32,2,34,1,1,3,3,4,4,13,618,1,1,3,86,1,1,13,154,3,50,1,2,94,3,1,108,2,14,1,5,1,2,1,6,3,2,24,1,4,1,1,1,1,4,3,4,30 ...

# %% [markdown]
# **Insight:**
# - tidak terdapat missing value
# - tidak terdapat duplicate data
# - ada sekitar 7% outliers di kolom payment value
# - ada sekitar 13% outliers di kolom order count

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Insight:**
# - Outlier tidak ditangani secara khusus karena diperlukan investigasi lebih lanjut untuk memastikan apakah outlier tersebut merupakan kesalahan data atau justru mencerminkan kondisi sebenarnya.
# - Selain itu, tidak dilakukan proses penghapusan (dropping) maupun imputasi data, karena hal tersebut tidak dibutuhkan untuk menjawab dua pertanyaan analisis yang telah disebutkan sebelumnya.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Show top 5 rows from df_ct based on 'order_count'
top_5_order_count = count_orders.nlargest(5, 'order_count')
top_5_order_count
# Out:
#        customer_city  order_count
# 3597       sao paulo        15046
# 3155  rio de janeiro         6604
# 453   belo horizonte         2697
# 558         brasilia         2071
# 1143        curitiba         1489

# %%
# Step 1: Merge df_od and df_ct on 'customer_id' to add 'customer_city' to df_od
merged_df = df_od.merge(df_ct[['customer_id', 'customer_city']], on='customer_id', how='left')

# Step 2: Merge the result with df_pm on 'order_id' to add 'payment_value'
merged_df = merged_df.merge(df_pm[['order_id', 'payment_value']], on='order_id', how='left')

# Step 3: Group by 'customer_city' and calculate the sum of 'payment_value'
payment_by_city = merged_df.groupby('customer_city')['payment_value'].sum().reset_index()

# %%
# Show top 5 rows from payment_by_city based on 'payment_value'
top_5_payment_by_city = payment_by_city.nlargest(5, 'payment_value')
top_5_payment_by_city
# Out:
#        customer_city  payment_value
# 3597       sao paulo     2203373.09
# 3155  rio de janeiro     1161927.36
# 453   belo horizonte      421765.12
# 558         brasilia      354216.78
# 1143        curitiba      247392.48

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Visualize Top 5 from df_ctn based on 'order_count'
fig_ctn = px.bar(top_5_order_count, 
                 x='customer_city', 
                 y='order_count', 
                 title="Top 5 Cities by Order Count", 
                 labels={'order_count': 'Order Count', 'customer_city': 'Customer City'},
                 color='customer_city')

# Show the first chart (Order Count)
fig_ctn.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45397e47-4e3a-4b4b-8f48-69872deec251" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45397e47-4e3a-4b4b-8f48-69872deec251")) {                    Plotly.newPlot(                        "45397e47-4e3a-4b4b-8f48-69872deec251",                        [{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003eOrder Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sao paulo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sao paulo","offsetgroup":"sao paulo","orientation":"v","showlegend":true,"textposition":"auto","x":["sao paulo"],"xaxis":"x","y":[15046],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003eOrder Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rio de janeiro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"rio de janeiro","offsetgroup":"rio de janeiro","orientation":"v","showlegend":true,"textposition":"auto","x":["rio de janeiro"],"xaxis":"x","y":[6604],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003eOrder Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"belo horizonte","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"belo horizonte","offsetgroup":"belo horizonte","orientation":"v","showlegend":true,"textposition":"auto","x":["belo horizonte"],"xaxis":"x","y":[2697],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003eOrder Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"brasilia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"brasilia","offsetgroup":"brasilia","orientation":"v","showlegend":true,"textposition":"auto","x":["brasilia"],"xaxis":"x","y":[2071],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003eOrder Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"curitiba","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"curitiba","offsetgroup":"curitiba","orientation":"v","showlegend":true,"textposition":"auto","x":["curitiba"],"xaxis":"x","y":[1489],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Visualize Top 5 from payment_by_city based on 'payment_value'
fig_payment = px.bar(top_5_payment_by_city, 
                     x='customer_city', 
                     y='payment_value', 
                     title="Top 5 Cities by Payment Value", 
                     labels={'payment_value': 'Payment Value', 'customer_city': 'Customer City'},
                     color='customer_city')

# Show the second chart (Payment Value)
fig_payment.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad4a60af-ed94-436c-9dc4-0eb2be35463d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad4a60af-ed94-436c-9dc4-0eb2be35463d")) {                    Plotly.newPlot(                        "ad4a60af-ed94-436c-9dc4-0eb2be35463d",                        [{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003ePayment Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sao paulo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sao paulo","offsetgroup":"sao paulo","orientation":"v","showlegend":true,"textposition":"auto","x":["sao paulo"],"xaxis":"x","y":[2203373.09],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003ePayment Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rio de janeiro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"rio de janeiro","offsetgroup":"rio de janeiro","orientation":"v","showlegend":true,"textposition":"auto","x":["rio de janeiro"],"xaxis":"x","y":[1161927.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003ePayment Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"belo horizonte","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"belo horizonte","offsetgroup":"belo horizonte","orientation":"v","showlegend":true,"textposition":"auto","x":["belo horizonte"],"xaxis":"x","y":[421765.12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003ePayment Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"brasilia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"brasilia","offsetgroup":"brasilia","orientation":"v","showlegend":true,"textposition":"auto","x":["brasilia"],"xaxis":"x","y":[354216.77999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer City=%{x}\u003cbr\u003ePayment Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"curitiba","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"curitiba","offsetgroup":"curitiba","orientation":"v","showlegend":true,"textposition":"auto","x":["curitiba"],"xaxis":"x","y":[247392.48],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Sejauh ini, perhitungan jumlah pesanan (order count) dan nilai pembayaran (payment value) menunjukkan konsistensi, di mana kota-kota dengan jumlah pesanan tinggi juga berkontribusi signifikan terhadap nilai transaksi yang besar.
